# %% [markdown]
# # Making Prototypes

# %%
import os
import numpy as np
import pandas as pd
from skimage.io import imread, imshow
from skimage.transform import resize
from skimage.feature import hog

path = "C:\\Users\\shwet\\Desktop\\archive\\fruits-360_dataset\\fruits-360\\Training"
all_Classes = os.listdir(path) 
prototypes = {}
prototypes_rgb = {}
cl_count = 0
for cl in all_Classes:
    proto = np.zeros((1100))
    count = 0
    red=0
    blue=0
    green=0
    for img in os.listdir(f'{path}\\{cl}'):
        fruit=imread(f'{path}\\{cl}\\{img}')
        vector = hog(fruit, orientations=11, pixels_per_cell = (15,15), cells_per_block = (2,2), multichannel=True)
        proto = proto+vector
        count+=1
        r=0
        g=0
        b=0
        ctr=0
        for x in range (0,100,1):
            for y in range(0,100,1):
                color = fruit[y,x]
                r=r+int(color[0])
                g=g+int(color[1])
                b=b+int(color[2])
                ctr=ctr+1
        red += r/ctr
        green += g/ctr
        blue += b/ctr
    prototypes_rgb[cl] = [(red/count),(green/count),(blue/count)]            
    proto = proto/count
    prototypes[cl] = proto
    cl_count+=1
    print("class: ",cl_count ,": ", cl," : done")
# Out:
# class:  1 :  Apple Braeburn  : done
# class:  2 :  Apple Crimson Snow  : done
# class:  3 :  Apple Golden 1  : done
# class:  4 :  Apple Golden 2  : done
# class:  5 :  Apple Golden 3  : done
# class:  6 :  Apple Granny Smith  : done
# class:  7 :  Apple Pink Lady  : done
# class:  8 :  Apple Red 1  : done
# class:  9 :  Apple Red 2  : done
# class:  10 :  Apple Red 3  : done
# class:  11 :  Apple Red Delicious  : done
# class:  12 :  Apple Red Yellow 1  : done
# class:  13 :  Apple Red Yellow 2  : done
# class:  14 :  Apricot  : done
# class:  15 :  Avocado  : done
# class:  16 :  Avocado ripe  : done
# class:  17 :  Banana  : done
# class:  18 :  Banana Lady Finger  : done
# class:  19 :  Banana Red  : done
# class:  20 :  Beetroot  : done
# class:  21 :  Blueberry  : done
# class:  22 :  Cactus fruit  : done
# class:  23 :  Cantaloupe 1  : done
# class:  24 :  Cantaloupe 2  : done
# class:  25 :  Carambula  : done
# class:  26 :  Cauliflower  : done
# class:  27 :  Cherry 1  : done
# class:  28 :  Cherry 2  : done
# class:  29 :  Cherry Rainier  : done
# class:  30 :  Cherry Wax Black  : done
# class:  31 :  Cherry Wax Red  : done
# class:  32 :  Cherry Wax Yellow  : done
# class:  33 :  Chestnut  : done
# class:  34 :  Clementine  : done
# class:  35 :  Cocos  : done
# class:  36 :  Corn  : done
# class:  37 :  Corn Husk  : done
# class:  38 :  Cucumber Ripe  : done
# class:  39 :  Cucumber Ripe 2  : done
# class:  40 :  Dates  : done
# class:  41 :  Eggplant  : done
# class:  42 :  Fig  : done
# class:  43 :  Ginger Root  : done
# class:  44 :  Granadilla  : done
# class:  45 :  Grape Blue  : done
# class:  46 :  Grape Pink  : done
# class:  47 :  Grape White  : done
# class:  48 :  Grape White 2  : done
# class:  49 :  Grape White 3  : done
# class:  50 :  Grape White 4  : done
# class:  51 :  Grapefruit Pink  : done
# class:  52 :  Grapefruit White  : done
# class:  53 :  Guava  : done
# class:  54 :  Hazelnut  : done
# class:  55 :  Huckleberry  : done
# class:  56 :  Kaki  : done
# class:  57 :  Kiwi  : done
# class:  58 :  Kohlrabi  : done
# class:  59 :  Kumquats  : done
# class:  60 :  Lemon  : done
# class:  61 :  Lemon Meyer  : done
# class:  62 :  Limes  : done
# class:  63 :  Lychee  : done
# class:  64 :  Mandarine  : done
# class:  65 :  Mango  : done
# class:  66 :  Mango Red  : done
# class:  67 :  Mangostan  : done
# class:  68 :  Maracuja  : done
# class:  69 :  Melon Piel de Sapo  : done
# class:  70 :  Mulberry  : done
# class:  71 :  Nectarine  : done
# class:  72 :  Nectarine Flat  : done
# class:  73 :  Nut Forest  : done
# class:  74 :  Nut Pecan  : done
# class:  75 :  Onion Red  : done
# class:  76 :  Onion Red Peeled  : done
# class:  77 :  Onion White  : done
# class:  78 :  Orange  : done
# class:  79 :  Papaya  : done
# class:  80 :  Passion Fruit  : done
# class:  81 :  Peach  : done
# class:  82 :  Peach 2  : done
# class:  83 :  Peach Flat  : done
# class:  84 :  Pear  : done
# class:  85 :  Pear 2  : done
# class:  86 :  Pear Abate  : done
# class:  87 :  Pear Forelle  : done
# class:  88 :  Pear Kaiser  : done
# class:  89 :  Pear Monster  : done
# class:  90 :  Pear Red  : done
# class:  91 :  Pear Stone  : done
# class:  92 :  Pear Williams  : done
# class:  93 :  Pepino  : done
# class:  94 :  Pepper Green  : done
# class:  95 :  Pepper Orange  : done
# class:  96 :  Pepper Red  : done
# class:  97 :  Pepper Yellow  : done
# class:  98 :  Physalis  : done
# class:  99 :  Physalis with Husk  : done
# class:  100 :  Pineapple  : done
# class:  101 :  Pineapple Mini  : done
# class:  102 :  Pitahaya Red  : done
# class:  103 :  Plum  : done
# class:  104 :  Plum 2  : done
# class:  105 :  Plum 3  : done
# class:  106 :  Pomegranate  : done
# class:  107 :  Pomelo Sweetie  : done
# class:  108 :  Potato Red  : done
# class:  109 :  Potato Red Washed  : done
# class:  110 :  Potato Sweet  : done
# class:  111 :  Potato White  : done
# class:  112 :  Quince  : done
# class:  113 :  Rambutan  : done
# class:  114 :  Raspberry  : done
# class:  115 :  Redcurrant  : done
# class:  116 :  Salak  : done
# class:  117 :  Strawberry  : done
# class:  118 :  Strawberry Wedge  : done
# class:  119 :  Tamarillo  : done
# class:  120 :  Tangelo  : done
# class:  121 :  Tomato 1  : done
# class:  122 :  Tomato 2  : done
# class:  123 :  Tomato 3  : done
# class:  124 :  Tomato 4  : done
# class:  125 :  Tomato Cherry Red  : done
# class:  126 :  Tomato Heart  : done
# class:  127 :  Tomato Maroon  : done
# class:  128 :  Tomato not Ripened  : done
# class:  129 :  Tomato Yellow  : done
# class:  130 :  Walnut  : done
# class:  131 :  Watermelon  : done

# %% [markdown]
# # Defining Euclidean Distance function

# %%
def Euclidean(v1,v2):
    import numpy as np
    # calculating Euclidean distance using linalg.norm()
    v1 = np.array(v1)
    v2 = np.array(v2)
    dist = np.linalg.norm(v1 - v2)
    return (dist)

# %%
prototypes_rgb
# Out:
# {'Apple Braeburn': [156.00409837398382, 101.32019004065044, 89.37390691056905],
#  'Apple Crimson Snow': [147.02901711711706,
#  'Tomato Cherry Red': [205.27741768292663,
#   97.72061646341453,
#   89.10219756097567],
#  'Tomato Heart': [141.06248260233937, 92.59346491228071, 89.43878918128654],
#  'Tomato Maroon': [154.06199673024523, 120.87316049046318, 108.75683160762935],
#  'Tomato not Ripened': [132.0525824894514,
#   146.42605126582285,
#   129.929438607595],
#  'Tomato Yellow': [219.2634729847493, 147.96860043572983, 85.85081503267973],
#  'Walnut': [154.38522544217707, 134.21400217687085, 125.0711692517007],
#  'Watermelon': [151.67353178947357, 160.8704962105263, 140.5806602105262]}

# %% [markdown]
# # Loading testing data and predicting classes

# %%
path2 = "C:\\Users\\shwet\\Desktop\\archive\\fruits-360_dataset\\fruits-360\\Test"
classes = os.listdir(path2) 
y_pred =[]    #list for classes predicted by the model
y_true =[]    #list for actual classes
for cla in classes:
    for img in os.listdir(f'{path2}\\{cla}'):
        fruit=imread(f'{path2}\\{cla}\\{img}')
        vector = hog(fruit, orientations=11, pixels_per_cell = (15,15), cells_per_block = (2,2), multichannel=True) #HOG vector for the test image
        list11=[]  # this list contains distances of the vector from all 131 prototypes
        list22=[]  # this list contains all 131 classes
        for cl in prototypes.keys():
            dis = Euclidean(prototypes[cl],vector)
            list11.append(dis)
            list22.append(cl)
        mini = min(list11)
        mini_ind = list11.index(mini)
        classObj = list22[mini_ind]    #variable storing the predicted class
        ############################# Testing from rgb prototypes of all classes ##########################3
        r=0
        g=0
        b=0
        ctr=0
        for x in range (0,100,1):
            for y in range(0,100,1):
                color = fruit[y,x]
                r=r+int(color[0])
                g=g+int(color[1])
                b=b+int(color[2])
                ctr=ctr+1
        r = r/ctr
        g = g/ctr
        b = b/ctr
        vector_rgb=[r,g,b]
        listRGB1 = []     # this list contains distances of the vector from all 131 prototypes
        listRGB2 = []     # this list contains all 131 classes
        for cl in prototypes_rgb.keys():
            distance = Euclidean(prototypes_rgb[cl],vector_rgb)
            listRGB1.append(distance)
            listRGB2.append(cl)
        minim = min(listRGB1)
        minim_ind = listRGB1.index(minim)
        classObjRGB = listRGB2[minim_ind]
        y_true.append(cla)
        if classObj == cla :
            y_pred.append(classObj)
        elif classObjRGB == cla:
            y_pred.append(classObjRGB)
        else:
            y_pred.append(classObjRGB)
    print("Class ",cla, "complete" )
# Out:
# Class  Apple Braeburn complete
# Class  Apple Crimson Snow complete
# Class  Apple Golden 1 complete
# Class  Apple Golden 2 complete
# Class  Apple Golden 3 complete
# Class  Apple Granny Smith complete
# Class  Apple Pink Lady complete
# Class  Apple Red 1 complete
# Class  Apple Red 2 complete
# Class  Apple Red 3 complete
# Class  Apple Red Delicious complete
# Class  Apple Red Yellow 1 complete
# Class  Apple Red Yellow 2 complete
# Class  Apricot complete
# Class  Avocado complete
# Class  Avocado ripe complete
# Class  Banana complete
# Class  Banana Lady Finger complete
# Class  Banana Red complete
# Class  Beetroot complete
# Class  Blueberry complete
# Class  Cactus fruit complete
# Class  Cantaloupe 1 complete
# Class  Cantaloupe 2 complete
# Class  Carambula complete
# Class  Cauliflower complete
# Class  Cherry 1 complete
# Class  Cherry 2 complete
# Class  Cherry Rainier complete
# Class  Cherry Wax Black complete
# Class  Cherry Wax Red complete
# Class  Cherry Wax Yellow complete
# Class  Chestnut complete
# Class  Clementine complete
# Class  Cocos complete
# Class  Corn complete
# Class  Corn Husk complete
# Class  Cucumber Ripe complete
# Class  Cucumber Ripe 2 complete
# Class  Dates complete
# Class  Eggplant complete
# Class  Fig complete
# Class  Ginger Root complete
# Class  Granadilla complete
# Class  Grape Blue complete
# Class  Grape Pink complete
# Class  Grape White complete
# Class  Grape White 2 complete
# Class  Grape White 3 complete
# Class  Grape White 4 complete
# Class  Grapefruit Pink complete
# Class  Grapefruit White complete
# Class  Guava complete
# Class  Hazelnut complete
# Class  Huckleberry complete
# Class  Kaki complete
# Class  Kiwi complete
# Class  Kohlrabi complete
# Class  Kumquats complete
# Class  Lemon complete
# Class  Lemon Meyer complete
# Class  Limes complete
# Class  Lychee complete
# Class  Mandarine complete
# Class  Mango complete
# Class  Mango Red complete
# Class  Mangostan complete
# Class  Maracuja complete
# Class  Melon Piel de Sapo complete
# Class  Mulberry complete
# Class  Nectarine complete
# Class  Nectarine Flat complete
# Class  Nut Forest complete
# Class  Nut Pecan complete
# Class  Onion Red complete
# Class  Onion Red Peeled complete
# Class  Onion White complete
# Class  Orange complete
# Class  Papaya complete
# Class  Passion Fruit complete
# Class  Peach complete
# Class  Peach 2 complete
# Class  Peach Flat complete
# Class  Pear complete
# Class  Pear 2 complete
# Class  Pear Abate complete
# Class  Pear Forelle complete
# Class  Pear Kaiser complete
# Class  Pear Monster complete
# Class  Pear Red complete
# Class  Pear Stone complete
# Class  Pear Williams complete
# Class  Pepino complete
# Class  Pepper Green complete
# Class  Pepper Orange complete
# Class  Pepper Red complete
# Class  Pepper Yellow complete
# Class  Physalis complete
# Class  Physalis with Husk complete
# Class  Pineapple complete
# Class  Pineapple Mini complete
# Class  Pitahaya Red complete
# Class  Plum complete
# Class  Plum 2 complete
# Class  Plum 3 complete
# Class  Pomegranate complete
# Class  Pomelo Sweetie complete
# Class  Potato Red complete
# Class  Potato Red Washed complete
# Class  Potato Sweet complete
# Class  Potato White complete
# Class  Quince complete
# Class  Rambutan complete
# Class  Raspberry complete
# Class  Redcurrant complete
# Class  Salak complete
# Class  Strawberry complete
# Class  Strawberry Wedge complete
# Class  Tamarillo complete
# Class  Tangelo complete
# Class  Tomato 1 complete
# Class  Tomato 2 complete
# Class  Tomato 3 complete
# Class  Tomato 4 complete
# Class  Tomato Cherry Red complete
# Class  Tomato Heart complete
# Class  Tomato Maroon complete
# Class  Tomato not Ripened complete
# Class  Tomato Yellow complete
# Class  Walnut complete
# Class  Watermelon complete

# %% [markdown]
# # Reporting accuracy, precision, recall and F1 score of our model

# %%
from sklearn.metrics import precision_score, recall_score, accuracy_score
accuracy = accuracy_score(y_true, y_pred)
precision = precision_score(y_true, y_pred, average='micro')
recall = recall_score(y_true, y_pred, average='macro')
F1 = 2 * (precision * recall) / (precision + recall)
print("Accuracy = ", accuracy*100 , "%")
print("Precision = ", precision*100 , "%")
print("Recall = ", recall)
print("F1 score = ", F1)
# Out:
# Accuracy =  58.93242826288183 %
# Precision =  58.93242826288183 %
# Recall =  0.5918928021818528
# F1 score =  0.5906057498226769
